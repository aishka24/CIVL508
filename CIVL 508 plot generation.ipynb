# %%
import plotly.graph_objects as go
import numpy as np
import plotly.express as px
import pandas as pd

# %%
#defining timestep
a = 0
n = 1
timestep = []

timestep.append(a)
while(n!=3000):
    n=n+1
    a = a+0.02
    timestep.append(a)
    
    
#timestep2 for ferndale
#defining timestep
a = 0
n = 1
timestep2 = []

timestep2.append(a)
while(n!=8511):
    n=n+1
    a = a+0.01
    timestep2.append(a)
    
#timestep3 for ferndale offshore
#defining timestep
a = 0
n = 1
timestep3 = []

timestep3.append(a)
while(n!=7002):
    n=n+1
    a = a+0.01
    timestep3.append(a)

# %%
fernoffdisp11 = pd.read_csv('/Users/aishweryaakapoor/Downloads/ferndaleoffshore-d1-new.txt',header=None)
fernoffdisp10 = pd.read_csv('/Users/aishweryaakapoor/Downloads/ferndaleoffshore-d2-new.txt',header=None)
fernoffdisp09 = pd.read_csv('/Users/aishweryaakapoor/Downloads/ferndaleoffshore-d3-new.txt',header=None)

# fernoffacc11 = pd.read_csv('/Users/aishweryaakapoor/Downloads/fernadaleoffshore-acce-1-new.txt',header=None)
fernoffacc11 = pd.read_csv('/Users/aishweryaakapoor/Downloads/ferndaleoffshore-a1-new.txt',header=None)
fernoffacc10 = pd.read_csv('/Users/aishweryaakapoor/Downloads/fernadaleoffshore-acce-2-new.txt',header=None)
fernoffacc09 = pd.read_csv('/Users/aishweryaakapoor/Downloads/fernadaleoffshore-acce-3-new.txt',header=None)

fernoffvel11 = pd.read_csv('/Users/aishweryaakapoor/Downloads/ferndaleoffshore-v1-new.txt',header=None)
fernoffvel10 = pd.read_csv('/Users/aishweryaakapoor/Downloads/fernadaleoffshore-vel-2-new.txt',header=None)
fernoffvel09 = pd.read_csv('/Users/aishweryaakapoor/Downloads/ferndaleoffshore-v3-new.txt',header=None)

petacc11 = pd.read_csv('/Users/aishweryaakapoor/Downloads/petrolia-acc-1-new.txt',header=None)
petacc10 = pd.read_csv('/Users/aishweryaakapoor/Downloads/petrolia-acc-2-new.txt',header=None)
petacc09 = pd.read_csv('/Users/aishweryaakapoor/Downloads/petrolia-acc-3-new.txt',header=None)

petvel11 = pd.read_csv('/Users/aishweryaakapoor/Downloads/petrolia-vel-1-new.txt',header=None)
petvel10 = pd.read_csv('/Users/aishweryaakapoor/Downloads/petrolia-vel-2-new.txt',header=None)
petvel09 = pd.read_csv('/Users/aishweryaakapoor/Downloads/petrolia-vel-3-new.txt',header=None)

# %%
#acceleration

df = pd.read_excel('/Users/aishweryaakapoor/Downloads/ferndale accel.xlsx')

mylist = []
with open('/Users/aishweryaakapoor/Downloads/Superman graphs/project data/acc/Petrolia aftershock 1CHAN009 1 col.txt','r') as f:
    for line in f:
        for word in line.split():
            mylist.append(float(word)/0.0254*0.3937/1000)

fig = go.Figure()
fig.add_trace(go.Scatter(x=timestep,y=petacc09[0],name='SAP2000 Output Values'))
fig.add_trace(go.Scatter(x=timestep,y=mylist,name='Actual Site Output Values'))
fig.update_layout(xaxis_title = 'time in seconds',yaxis_title='unit - cm/s2',title='Channel 9 Acceleration Petrolia',template='simple_white',colorway=['rgb(247,104,161)','rgb(65,182,196)'])
fig.show()

mylist = []
with open('/Users/aishweryaakapoor/Downloads/Superman graphs/project data/acc/Petrolia aftershock 1CHAN010 1 col.txt','r') as f:
    for line in f:
        for word in line.split():
            mylist.append(float(word)/0.0254*0.3937/300)

fig = go.Figure()
fig.add_trace(go.Scatter(x=timestep,y=petacc10[0],name='SAP2000 Output Values'))
fig.add_trace(go.Scatter(x=timestep,y=mylist,name='Actual Site Output Values'))
fig.update_layout(xaxis_title = 'time in seconds',yaxis_title='unit - cm/s2',title='Channel 10 Acceleration Petrolia',template='simple_white',colorway=['rgb(247,104,161)','rgb(65,182,196)'])
fig.show()

mylist = []
with open('/Users/aishweryaakapoor/Downloads/Superman graphs/project data/acc/Petrolia aftershock 1CHAN011 1 col.txt','r') as f:
    for line in f:
        for word in line.split():
            mylist.append(float(word)/0.0254*0.3937/500)

fig = go.Figure()
fig.add_trace(go.Scatter(x=timestep,y=petacc11[0],name='SAP2000 Output Values'))
fig.add_trace(go.Scatter(x=timestep,y=mylist,name='Actual Site Output Values'))
fig.update_layout(xaxis_title = 'time in seconds',yaxis_title='unit - cm/s2',title='Channel 11 Acceleration Petrolia',template='simple_white',colorway=['rgb(247,104,161)','rgb(65,182,196)'])
fig.show()

mylist = []
with open('/Users/aishweryaakapoor/Downloads/Superman graphs/project data/acc/Ferndale CHA009 1 col.txt','r') as f:
    for line in f:
        for word in line.split():
            mylist.append(float(word)/0.0254*0.3937/500)

fig = go.Figure()
fig.add_trace(go.Scatter(x=timestep2,y=df['U3'],name='SAP2000 Output Values'))
fig.add_trace(go.Scatter(x=timestep2,y=mylist,name='Actual Site Output Values'))
fig.update_layout(xaxis_title = 'time in seconds',yaxis_title='unit - cm/s2',title='Channel 9 Acceleration Ferndale',template='simple_white',colorway=['rgb(247,104,161)','rgb(65,182,196)'])
fig.show()

mylist = []
with open('/Users/aishweryaakapoor/Downloads/Superman graphs/project data/acc/Ferndale CHA010 1 col.txt','r') as f:
    for line in f:
        for word in line.split():
            mylist.append(float(word)/0.0254*0.3937/250)

fig = go.Figure()
fig.add_trace(go.Scatter(x=timestep2,y=df['U2'],name='SAP2000 Output Values'))
fig.add_trace(go.Scatter(x=timestep2,y=mylist,name='Actual Site Output Values'))
fig.update_layout(xaxis_title = 'time in seconds',yaxis_title='unit - cm/s2',title='Channel 10 Acceleration Ferndale',template='simple_white',colorway=['rgb(247,104,161)','rgb(65,182,196)'])
fig.show()

mylist = []
with open('/Users/aishweryaakapoor/Downloads/Superman graphs/project data/acc/Ferndale CHA011 1 col.txt','r') as f:
    for line in f:
        for word in line.split():
            mylist.append(float(word)/0.0254*0.3937/250)

fig = go.Figure()
fig.add_trace(go.Scatter(x=timestep2,y=df['U1'],name='SAP2000 Output Values'))
fig.add_trace(go.Scatter(x=timestep2,y=mylist,name='Actual Site Output Values'))
fig.update_layout(xaxis_title = 'time in seconds',yaxis_title='unit - cm/s2',title='Channel 11 Acceleration Ferndale',template='simple_white',colorway=['rgb(247,104,161)','rgb(65,182,196)'])
fig.show()


mylist = []
with open('/Users/aishweryaakapoor/Downloads/Superman graphs/project data/acc/ferndaleoffshoreCHA009 1 col.txt','r') as f:
    for line in f:
        for word in line.split():
            mylist.append(float(word)/50)

fig = go.Figure()
fig.add_trace(go.Scatter(x=timestep3,y=fernoffacc11[0],name='SAP2000 Output Values'))
fig.add_trace(go.Scatter(x=timestep3,y=mylist,name='Actual Site Output Values'))
fig.update_layout(xaxis_title = 'time in seconds',yaxis_title='unit - cm/s2',title='Channel 9 Acceleration Ferndale Offshore',template='simple_white',colorway=['rgb(247,104,161)','rgb(65,182,196)'])
fig.show()

mylist = []
with open('/Users/aishweryaakapoor/Downloads/Superman graphs/project data/acc/ferndaleoffshoreCHA010 1 col.txt','r') as f:
    for line in f:
        for word in line.split():
            mylist.append(float(word)/25)

fig = go.Figure()
fig.add_trace(go.Scatter(x=timestep3,y=fernoffacc11[0],name='SAP2000 Output Values'))
fig.add_trace(go.Scatter(x=timestep3,y=mylist,name='Actual Site Output Values'))
fig.update_layout(xaxis_title = 'time in seconds',yaxis_title='unit - cm/s2',title='Channel 10 Acceleration Ferndale Offshore',template='simple_white',colorway=['rgb(247,104,161)','rgb(65,182,196)'])
fig.show()

mylist = []
with open('/Users/aishweryaakapoor/Downloads/Superman graphs/project data/acc/ferndaleoffshoreCHA011 1 col.txt','r') as f:
    for line in f:
        for word in line.split():
            mylist.append(float(word)/50)

fig = go.Figure()
fig.add_trace(go.Scatter(x=timestep3,y=fernoffacc11[0],name='SAP2000 Output Values'))
fig.add_trace(go.Scatter(x=timestep3,y=mylist,name='Actual Site Output Values'))
fig.update_layout(xaxis_title = 'time in seconds',yaxis_title='unit - cm/s2',title='Channel 11 Acceleration Ferndale Offshore',template='simple_white',colorway=['rgb(247,104,161)','rgb(65,182,196)'])
fig.show()

# %%
#displacement

import plotly.graph_objects as go
import numpy as np
import plotly.express as px
import pandas as pd

df = pd.read_excel('/Users/aishweryaakapoor/Downloads/123456789.xlsx')
df2 = pd.read_excel('/Users/aishweryaakapoor/Downloads/ferndale-disp.xlsx')
# df = pd.read_excel('/Users/aishweryaakapoor/Downloads/786.xlsx')


mylist = []
with open('/Users/aishweryaakapoor/Downloads/Superman graphs/project data/disp/Petro Displ CHA011.txt','r') as f:
    for line in f:
        for word in line.split():
            mylist.append(float(word)/0.0254*0.3937/10000)
fig = go.Figure()
fig.add_trace(go.Scatter(x=timestep,y=df['U1'],name='SAP2000 Output Values'))
fig.add_trace(go.Scatter(x=timestep,y=mylist,name='Actual Site Output Values'))
fig.update_layout(xaxis_title = 'time in seconds',yaxis_title='unit - cm',title='Channel 11 Displacement Petrolia',template='simple_white',colorway=['rgb(247,104,161)','rgb(65,182,196)'])
fig.show()

mylist = []
with open('/Users/aishweryaakapoor/Downloads/Superman graphs/project data/disp/Petro Displ CHA010.txt','r') as f:
    for line in f:
        for word in line.split():
            mylist.append(float(word)/0.0254*0.3937/10000)
fig = go.Figure()
fig.add_trace(go.Scatter(x=timestep,y=df['U2'],name='SAP2000 Output Values'))
fig.add_trace(go.Scatter(x=timestep,y=mylist,name='Actual Site Output Values'))
fig.update_layout(xaxis_title = 'time in seconds',yaxis_title='unit - cm',title='Channel 10 Displacement Petrolia',template='simple_white',colorway=['rgb(247,104,161)','rgb(65,182,196)'])

fig.show()

mylist = []
with open('/Users/aishweryaakapoor/Downloads/Superman graphs/project data/disp/Petro Displ CHA009.txt','r') as f:
    for line in f:
        for word in line.split():
            mylist.append(float(word)/0.0254*0.3937/10000)
fig = go.Figure()
fig.add_trace(go.Scatter(x=timestep,y=df['U3'],name='SAP2000 Output Values'))
fig.add_trace(go.Scatter(x=timestep,y=mylist,name='Actual Site Output Values'))
fig.update_layout(xaxis_title = 'time in seconds',yaxis_title='unit - cm',title='Channel 9 Displacement Petrolia',template='simple_white',colorway=['rgb(247,104,161)','rgb(65,182,196)'])
fig.show()

mylist = []
with open('/Users/aishweryaakapoor/Downloads/Superman graphs/project data/disp/Ferndale displ CHA011.txt','r') as f:
    for line in f:
        for word in line.split():
            mylist.append(float(word)/64)
fig = go.Figure()
fig.add_trace(go.Scatter(x=timestep2,y=df2['U1'],name='SAP2000 Output Values'))
fig.add_trace(go.Scatter(x=timestep2,y=mylist,name='Actual Site Output Values'))
fig.update_layout(xaxis_title = 'time in seconds',yaxis_title='unit - cm',title='Channel 11 Displacement Ferndale',template='simple_white',colorway=['rgb(247,104,161)','rgb(65,182,196)'])
fig.show()

mylist = []
with open('/Users/aishweryaakapoor/Downloads/Superman graphs/project data/disp/Ferndale displ CHA010.txt','r') as f:
    for line in f:
        for word in line.split():
            mylist.append(float(word)/64)
fig = go.Figure()
fig.add_trace(go.Scatter(x=timestep2,y=df2['U2'],name='SAP2000 Output Values'))
fig.add_trace(go.Scatter(x=timestep2,y=mylist,name='Actual Site Output Values'))
fig.update_layout(xaxis_title = 'time in seconds',yaxis_title='unit - cm',title='Channel 10 Displacement Ferndale',template='simple_white',colorway=['rgb(247,104,161)','rgb(65,182,196)'])

fig.show()

mylist = []
with open('/Users/aishweryaakapoor/Downloads/Superman graphs/project data/disp/Ferndale displ CHA009.txt','r') as f:
    for line in f:
        for word in line.split():
            mylist.append(float(word)/0.0254*0.3937/10000)
fig = go.Figure()
fig.add_trace(go.Scatter(x=timestep2,y=df2['U3'],name='SAP2000 Output Values'))
fig.add_trace(go.Scatter(x=timestep2,y=mylist,name='Actual Site Output Values'))
fig.update_layout(xaxis_title = 'time in seconds',yaxis_title='unit - cm',title='Channel 9 Displacement Ferndale',template='simple_white',colorway=['rgb(247,104,161)','rgb(65,182,196)'])
fig.show()

mylist = []
with open('/Users/aishweryaakapoor/Downloads/Superman graphs/project data/disp/ferndaleoffshore displ CHA011.txt','r') as f:
    for line in f:
        for word in line.split():
            mylist.append(float(word)/100)
fig = go.Figure()
fig.add_trace(go.Scatter(x=timestep3,y=fernoffdisp11[0],name='SAP2000 Output Values'))
fig.add_trace(go.Scatter(x=timestep3,y=mylist,name='Actual Site Output Values'))
fig.update_layout(xaxis_title = 'time in seconds',yaxis_title='unit - cm',title='Channel 11 Displacement Ferndale Offshore',template='simple_white',colorway=['rgb(247,104,161)','rgb(65,182,196)'])
fig.show()

mylist = []
with open('/Users/aishweryaakapoor/Downloads/Superman graphs/project data/disp/ferndaleoffshore displ CHA010.txt','r') as f:
    for line in f:
        for word in line.split():
            mylist.append(float(word)/100)
fig = go.Figure()
fig.add_trace(go.Scatter(x=timestep3,y=fernoffdisp10[0],name='SAP2000 Output Values'))
fig.add_trace(go.Scatter(x=timestep3,y=mylist,name='Actual Site Output Values'))
fig.update_layout(xaxis_title = 'time in seconds',yaxis_title='unit - cm',title='Channel 10 Displacement Ferndale Offshore',template='simple_white',colorway=['rgb(247,104,161)','rgb(65,182,196)'])

fig.show()

mylist = []
with open('/Users/aishweryaakapoor/Downloads/Superman graphs/project data/disp/ferndaleoffshore displ CHA009.txt','r') as f:
    for line in f:
        for word in line.split():
            mylist.append(float(word)/100)
fig = go.Figure()
fig.add_trace(go.Scatter(x=timestep3,y=fernoffdisp09[0],name='SAP2000 Output Values'))
fig.add_trace(go.Scatter(x=timestep3,y=mylist,name='Actual Site Output Values'))
fig.update_layout(xaxis_title = 'time in seconds',yaxis_title='unit - cm',title='Channel 9 Displacement Ferndale Offshore',template='simple_white',colorway=['rgb(247,104,161)','rgb(65,182,196)'])
fig.show()

# %%
#velocity

import plotly.graph_objects as go
import numpy as np
import plotly.express as px
import pandas as pd

# df = pd.read_excel('/Users/aishweryaakapoor/Downloads/123456789.xlsx')
df2 = pd.read_excel('/Users/aishweryaakapoor/Downloads/fernmdale-vleo.xlsx')

mylist = []
with open('/Users/aishweryaakapoor/Downloads/Superman graphs/project data/vel/Petrolia velc CHAN011.txt','r') as f:
    for line in f:
        for word in line.split():
            mylist.append(float(word)/25)
#             mylist.append(float(word))
fig = go.Figure()
fig.add_trace(go.Scatter(x=timestep,y=petvel11[0],name='SAP2000 Output Values'))
fig.add_trace(go.Scatter(x=timestep,y=mylist,name='Actual Site Output Values'))
fig.update_layout(xaxis_title='time in seconds',yaxis_title='cm/s',title='Channel 11 Velocity Petrolia',template='simple_white',colorway=['rgb(247,104,161)','rgb(65,182,196)'])
fig.show()

mylist = []
with open('/Users/aishweryaakapoor/Downloads/Superman graphs/project data/vel/Petrolia velc CHAN010.txt','r') as f:
    for line in f:
        for word in line.split():
            mylist.append(float(word)/25)
#             mylist.append(float(word))
fig = go.Figure()
fig.add_trace(go.Scatter(x=timestep,y=petvel10[0],name='SAP2000 Output Values'))
fig.add_trace(go.Scatter(x=timestep,y=mylist,name='Actual Site Output Values'))
fig.update_layout(xaxis_title='time in seconds',yaxis_title='cm/s',title='Channel 10 Velocity Petrolia',template='simple_white',colorway=['rgb(247,104,161)','rgb(65,182,196)'])

fig.show()

mylist = []
with open('/Users/aishweryaakapoor/Downloads/Superman graphs/project data/vel/Petrolia velc CHAN009.txt','r') as f:
    for line in f:
        for word in line.split():
            mylist.append(float(word)/25)
#             mylist.append(float(word))
    fig = go.Figure()
fig.add_trace(go.Scatter(x=timestep,y=petvel09[0],name='SAP2000 Output Values'))
fig.add_trace(go.Scatter(x=timestep,y=mylist,name='Actual Site Output Values'))
fig.update_layout(xaxis_title='time in seconds',yaxis_title='cm/s',title='Channel 9 Velocity Petrolia',template='simple_white',colorway=['rgb(247,104,161)','rgb(65,182,196)'])
fig.show()

mylist = []
with open('/Users/aishweryaakapoor/Downloads/Superman graphs/project data/vel/Ferndale Velc CHA011.txt','r') as f:
    for line in f:
        for word in line.split():
            mylist.append(float(word)/25)
fig = go.Figure()
fig.add_trace(go.Scatter(x=timestep2,y=df2['U1'],name='SAP2000 Output Values'))
fig.add_trace(go.Scatter(x=timestep2,y=mylist,name='Actual Site Output Values'))
fig.update_layout(xaxis_title='time in seconds',yaxis_title='cm/s',title='Channel 11 Velocity Ferndale',template='simple_white',colorway=['rgb(247,104,161)','rgb(65,182,196)'])
fig.show()

mylist = []
with open('/Users/aishweryaakapoor/Downloads/Superman graphs/project data/vel/Ferndale Velc CHA010.txt','r') as f:
    for line in f:
        for word in line.split():
            mylist.append(float(word)/25)
fig = go.Figure()
fig.add_trace(go.Scatter(x=timestep2,y=df2['U2'],name='SAP2000 Output Values'))
fig.add_trace(go.Scatter(x=timestep2,y=mylist,name='Actual Site Output Values'))
fig.update_layout(xaxis_title='time in seconds',yaxis_title='cm/s',title='Channel 10 Velocity Ferndale',template='simple_white',colorway=['rgb(247,104,161)','rgb(65,182,196)'])

fig.show()

mylist = []
with open('/Users/aishweryaakapoor/Downloads/Superman graphs/project data/vel/Ferndale Velc CHA009.txt','r') as f:
    for line in f:
        for word in line.split():
            mylist.append(float(word)/200)
fig = go.Figure()
fig.add_trace(go.Scatter(x=timestep2,y=df2['U3'],name='SAP2000 Output Values'))
fig.add_trace(go.Scatter(x=timestep2,y=mylist,name='Actual Site Output Values'))
fig.update_layout(xaxis_title='time in seconds',yaxis_title='cm/s',title='Channel 9 Velocity Ferndale',template='simple_white',colorway=['rgb(247,104,161)','rgb(65,182,196)'])
fig.show()

mylist = []
with open('/Users/aishweryaakapoor/Downloads/Superman graphs/project data/vel/ferndaleoffshore velcCHA011.txt','r') as f:
    for line in f:
        for word in line.split():
            mylist.append(float(word)/100)
fig = go.Figure()
fig.add_trace(go.Scatter(x=timestep3,y=fernoffvel11[0],name='SAP2000 Output Values'))
fig.add_trace(go.Scatter(x=timestep3,y=mylist,name='Actual Site Output Values'))
fig.update_layout(xaxis_title='time in seconds',yaxis_title='cm/s',title='Channel 11 Velocity Ferndale Offshore',template='simple_white',colorway=['rgb(247,104,161)','rgb(65,182,196)'])
fig.show()

mylist = []
with open('/Users/aishweryaakapoor/Downloads/Superman graphs/project data/vel/ferndaleoffshore velcCHA010.txt','r') as f:
    for line in f:
        for word in line.split():
            mylist.append(float(word)/50)
fig = go.Figure()
fig.add_trace(go.Scatter(x=timestep3,y=fernoffvel10[0],name='SAP2000 Output Values'))
fig.add_trace(go.Scatter(x=timestep3,y=mylist,name='Actual Site Output Values'))
fig.update_layout(xaxis_title='time in seconds',yaxis_title='cm/s',title='Channel 10 Velocity Ferndale Offshore',template='simple_white',colorway=['rgb(247,104,161)','rgb(65,182,196)'])
fig.show()

mylist = []
with open('/Users/aishweryaakapoor/Downloads/Superman graphs/project data/vel/ferndaleoffshore velcCHA009.txt','r') as f:
    for line in f:
        for word in line.split():
            mylist.append(float(word)/50)
fig = go.Figure()
fig.add_trace(go.Scatter(x=timestep3,y=fernoffvel09[0],name='SAP2000 Output Values'))
fig.add_trace(go.Scatter(x=timestep3,y=mylist,name='Actual Site Output Values'))
fig.update_layout(xaxis_title='time in seconds',yaxis_title='cm/s',title='Channel 9 Velocity Ferndale Offshore',template='simple_white',colorway=['rgb(247,104,161)','rgb(65,182,196)'])
fig.show()

# %%
#response spectra file processing

mylist = []
timestamp = []
c=0
with open('/Users/aishweryaakapoor/Downloads/FERNDALE-RESPONSE SPECTRA.txt','r') as f:
    for line in f:
        for word in line.split():
            c=c+1
            if(c%2!=0):
                timestamp.append(float(word))
            if(c%2==0):
                mylist.append(float(word))
                
df = pd.DataFrame(list(zip(timestamp,mylist)))
df.to_csv('FERNDALE-RESPONSE SPECTRA-new.csv',index=False)

mylist = []
timestamp = []
c=0
with open('/Users/aishweryaakapoor/Downloads/FERNDALEOFFSHORE-RESPONSE SPECTRA.txt','r') as f:
    for line in f:
        for word in line.split():
            c=c+1
            if(c%2!=0):
                timestamp.append(float(word))
            if(c%2==0):
                mylist.append(float(word))
                
df = pd.DataFrame(list(zip(timestamp,mylist)))
df.to_csv('FERNDALEOFFSHORE-RESPONSE SPECTRA-new.csv',index=False)

mylist = []
timestamp = []
c=0
with open('/Users/aishweryaakapoor/Downloads/PETROLIA- RESPONSE SPECTRA.txt','r') as f:
    for line in f:
        for word in line.split():
            c=c+1
            if(c%2!=0):
                timestamp.append(float(word))
            if(c%2==0):
                mylist.append(float(word))
                
df = pd.DataFrame(list(zip(timestamp,mylist)))
df.to_csv('PETROLIA- RESPONSE SPECTRA-new.csv',index=False)
